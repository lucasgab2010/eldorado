# %%
import pandas as pd
import numpy as np
#d = pd.read_csv('datog.csv' ,  encoding= 'ISO-8859-1')
f = pd.read_excel('datogg.xlsx')

# %%
f
# Out:
#        Remito      Fecha                                  Cliente  \
# 0       25923 2018-01-02                             Dicon S.R.L.
# 1       25924 2018-01-03  Consejo Profesional Ciencias Económicas
# 2       25925 2018-01-03  Consejo Profesional Ciencias Económicas
# 3       25927 2018-01-04                             Dicon S.R.L.
# 4       25928 2018-01-04                            El Dorado SRL
# ...       ...        ...                                      ...
# 13127   45366 2023-07-31                             Dicon S.R.L.
# 13128   45367 2023-07-31                             Dicon S.R.L.
# 13129   45368 2023-07-31                             Dicon S.R.L.
# 13130   45369 2023-07-31                             Dicon S.R.L.
# 13131   45370 2023-07-31                             Dicon S.R.L.
#
#       Obra/Dirección             Barrio Hora Pedido Frecuencia  \
# 0           Portolan         Margen Sur    15:00:00   00:30:00
# ...

# %%
f.isnull()
# Out:
#        Remito  Fecha  Cliente  Obra/Dirección  Barrio  Hora Pedido  \
# 0       False  False    False           False   False        False
# 1       False  False    False           False   False        False
# 2       False  False    False           False   False         True
# 3       False  False    False           False   False        False
# 4       False  False    False           False   False        False
# ...       ...    ...      ...             ...     ...          ...
# 13127   False  False    False           False   False         True
# 13128   False  False    False           False   False         True
# 13129   False  False    False           False   False         True
# 13130   False  False    False           False   False         True
# 13131   False  False    False           False   False         True
#
#        Frecuencia  Hora Carga Planta  Llegada Obra  Inicio descarga  ...  \
# 0           False              False         False             True  ...
# ...

# %%
f.isnull().sum()
# Out:
# Remito                                               0
# Fecha                                                0
# Cliente                                              5
# Obra/Dirección                                      30
# Barrio                                             701
# Hora Pedido                                       8535
# Frecuencia                                        9614
# Hora Carga Planta                                  403
# Llegada Obra                                       828
# Inicio descarga                                   6008
# Fin Descarga                                       840
# Salida Obra                                       6035
# Llegada Planta                                    1750
# Patente Bomba                                    12974
# Patente Mixer                                      221
# Chofer Mixer                                       191
# Tipo Obra                                         4885
# ...

# %%
f = f.dropna(subset=['Cliente'])

# %%
f = f.dropna(subset=['Obra/Dirección'])

# %%
f = f.dropna(subset=['Barrio'])

# %%
f = f.dropna(subset=['Hora Carga Planta'])

# %%
f = f.dropna(subset=['Llegada Obra'])

# %%
f = f.dropna(subset=['Salida Obra'])

# %%
f
# Out:
#        Remito      Fecha                   Cliente      Obra/Dirección  \
# 5628    37060 2021-06-02  MUNICIPALIDAD RIO GRANDE  USHUAIA Y SANTA FE
# 5629    37061 2021-06-02                  TV FUEGO          BROWN 1546
# 5630    37062 2021-06-02                 NAKON SUR        GALPON MUÑOZ
# 5631    37063 2021-06-02  MUNICIPALIDAD RIO GRANDE       TOLHUIN Y KAU
# 5632    37064 2021-06-03              TAPIA ANDRES      KARACACHOF 485
# ...       ...        ...                       ...                 ...
# 13127   45366 2023-07-31              Dicon S.R.L.           RIO CHICO
# 13128   45367 2023-07-31              Dicon S.R.L.           RIO CHICO
# 13129   45368 2023-07-31              Dicon S.R.L.           RIO CHICO
# 13130   45369 2023-07-31              Dicon S.R.L.           RIO CHICO
# 13131   45370 2023-07-31              Dicon S.R.L.           RIO CHICO
#
#                   Barrio Hora Pedido           Frecuencia Hora Carga Planta  \
# ...

# %%
f.isnull().sum()
# Out:
# Remito                                              0
# Fecha                                               0
# Cliente                                             0
# Obra/Dirección                                      0
# Barrio                                              0
# Hora Pedido                                      4372
# Frecuencia                                       5133
# Hora Carga Planta                                   0
# Llegada Obra                                        0
# Inicio descarga                                     1
# Fin Descarga                                        0
# Salida Obra                                         0
# Llegada Planta                                     58
# Patente Bomba                                    6565
# Patente Mixer                                       5
# Chofer Mixer                                       40
# Tipo Obra                                          28
# ...

# %%
f = f.dropna(subset=['Inicio descarga'])

# %%
f = f.dropna(subset=['Llegada Planta'])

# %%
f = f.dropna(subset=['Patente Mixer'])

# %%
f = f.dropna(subset=['Chofer Mixer'])

# %%
f = f.dropna(subset=['Tipo Obra'])

# %%
f = f.dropna(subset=['Medio Descarga'])

# %%
f = f.dropna(subset=['Formula'])

# %%
f.isnull().sum()
# Out:
# Remito                                              0
# Fecha                                               0
# Cliente                                             0
# Obra/Dirección                                      0
# Barrio                                              0
# Hora Pedido                                      4285
# Frecuencia                                       5007
# Hora Carga Planta                                   0
# Llegada Obra                                        0
# Inicio descarga                                     0
# Fin Descarga                                        0
# Salida Obra                                         0
# Llegada Planta                                      0
# Patente Bomba                                    6424
# Patente Mixer                                       0
# Chofer Mixer                                        0
# Tipo Obra                                           0
# ...

# %%
f
# Out:
#        Remito      Fecha                   Cliente      Obra/Dirección  \
# 5628    37060 2021-06-02  MUNICIPALIDAD RIO GRANDE  USHUAIA Y SANTA FE
# 5629    37061 2021-06-02                  TV FUEGO          BROWN 1546
# 5630    37062 2021-06-02                 NAKON SUR        GALPON MUÑOZ
# 5631    37063 2021-06-02  MUNICIPALIDAD RIO GRANDE       TOLHUIN Y KAU
# 5632    37064 2021-06-03              TAPIA ANDRES      KARACACHOF 485
# ...       ...        ...                       ...                 ...
# 13127   45366 2023-07-31              Dicon S.R.L.           RIO CHICO
# 13128   45367 2023-07-31              Dicon S.R.L.           RIO CHICO
# 13129   45368 2023-07-31              Dicon S.R.L.           RIO CHICO
# 13130   45369 2023-07-31              Dicon S.R.L.           RIO CHICO
# 13131   45370 2023-07-31              Dicon S.R.L.           RIO CHICO
#
#                   Barrio Hora Pedido           Frecuencia Hora Carga Planta  \
# ...

# %%
f = f.dropna(subset=['Tipo de Hº'])

# %%
f = f.dropna(subset=['Aditivo Fluidificante en Planta(Tipo/ Marca)'])

# %%
f = f.dropna(subset=['(Fluidif)Kg'])

# %%
f.isnull().sum()
# Out:
# Remito                                              0
# Fecha                                               0
# Cliente                                             0
# Obra/Dirección                                      0
# Barrio                                              0
# Hora Pedido                                      2967
# Frecuencia                                       3324
# Hora Carga Planta                                   0
# Llegada Obra                                        0
# Inicio descarga                                     0
# Fin Descarga                                        0
# Salida Obra                                         0
# Llegada Planta                                      0
# Patente Bomba                                    4517
# Patente Mixer                                       0
# Chofer Mixer                                        0
# Tipo Obra                                           0
# ...

# %%
f.to_excel('dat.xlsx')

# %%
d = pd.read_excel('dat.xlsx')

# %%
d.isnull().sum()
# Out:
# Unnamed: 0                                          0
# Remito                                              0
# Fecha                                               0
# Cliente                                             0
# Obra/Dirección                                      0
# Barrio                                              0
# Hora Pedido                                      2967
# Frecuencia                                       3324
# Hora Carga Planta                                   0
# Llegada Obra                                        0
# Inicio descarga                                     0
# Fin Descarga                                        0
# Salida Obra                                         0
# Llegada Planta                                      0
# Patente Bomba                                    4517
# Patente Mixer                                       0
# Chofer Mixer                                        0
# ...

# %%
d
# Out:
#       Unnamed: 0  Remito      Fecha                   Cliente  \
# 0           5628   37060 2021-06-02  MUNICIPALIDAD RIO GRANDE
# 1           5629   37061 2021-06-02                  TV FUEGO
# 2           5630   37062 2021-06-02                 NAKON SUR
# 3           5631   37063 2021-06-02  MUNICIPALIDAD RIO GRANDE
# 4           5632   37064 2021-06-03              TAPIA ANDRES
# ...          ...     ...        ...                       ...
# 4580       13127   45366 2023-07-31              Dicon S.R.L.
# 4581       13128   45367 2023-07-31              Dicon S.R.L.
# 4582       13129   45368 2023-07-31              Dicon S.R.L.
# 4583       13130   45369 2023-07-31              Dicon S.R.L.
# 4584       13131   45370 2023-07-31              Dicon S.R.L.
#
#           Obra/Dirección             Barrio Hora Pedido           Frecuencia  \
# 0     USHUAIA Y SANTA FE             Mutual    10:30:00             01:00:00
# ...
